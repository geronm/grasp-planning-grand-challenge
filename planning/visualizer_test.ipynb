# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, rc, rcParams
import matplotlib.ticker as ticker
from IPython.display import HTML
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from graphics import Grid
from simulator import SimObject, Simulator
rc('animation', html='html5')
# rcParams['animation.writer'] = 'avconv'

# %%
objarr =[[1]]
#objarr =[[0,1],[1,1],[1,1]]
obj = SimObject(3,3,objarr)

sim = Simulator(10,8,obj)

grid = Grid([], sim.width, sim.height)

# %%
grid.visualize_grasp_sequences(sim, [[[0.5, 0.5]], [[0.9, 0.1]], [[0.1, 0.8]], [[0.1, 0.6]]], [(2, 0), (3, 0), (3, 1), (5, 1)])
# Out:
# drawing horizontal gripper
# drawing horizontal gripper
# ('Final_x_y', 2, 2)
# ('Self x, y', 1, 2)
# ('Total path', [(1.0, 2.0), (1.02, 2.0), (1.04, 2.0), (1.06, 2.0), (1.08, 2.0), (1.1, 2.0), (1.12, 2.0), (1.1400000000000001, 2.0), (1.16, 2.0), (1.18, 2.0), (1.2, 2.0), (1.22, 2.0), (1.24, 2.0), (1.26, 2.0), (1.28, 2.0), (1.3, 2.0), (1.32, 2.0), (1.34, 2.0), (1.3599999999999999, 2.0), (1.38, 2.0), (1.4, 2.0), (1.42, 2.0), (1.44, 2.0), (1.46, 2.0), (1.48, 2.0), (1.5, 2.0), (1.52, 2.0), (1.54, 2.0), (1.56, 2.0), (1.58, 2.0), (1.6, 2.0), (1.62, 2.0), (1.6400000000000001, 2.0), (1.6600000000000001, 2.0), (1.6800000000000002, 2.0), (1.7000000000000002, 2.0), (1.72, 2.0), (1.74, 2.0), (1.76, 2.0), (1.78, 2.0), (1.8, 2.0), (1.82, 2.0), (1.8399999999999999, 2.0), (1.8599999999999999, 2.0), (1.88, 2.0), (1.9, 2.0), (1.92, 2.0), (1.94, 2.0), (1.96, 2.0), (1.98, 2.0), (2.0, 2.0)])
# drawing horizontal gripper
# drawing horizontal gripper
# ('Final_x_y', 3, 3)
# ('Self x, y', 1, 3)
# ...

# %%
grid.play()
# Out:
# ('Loading new scene', 0)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x1174d5a90>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x1174d5110>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x1174d5d90>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x1174d5e50>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x1174d5690>)
# ('Removing old scene', 0)
# ('Loading new scene', 1)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x1174d5050>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x11a903ad0>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x11a903f50>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x11a903950>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x11a903590>)
# ('Removing old scene', 1)
# ('Loading new scene', 2)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x11a903710>)
# ...

# %%
grid.visualize_grasp_sequence(sim, None, (3, 1))
# Out:
# drawing vertical gripper
# ('Final_x_y', 3, 3)
# ('Self x, y', 3, 1)
# ('Total path', [(3.0, 1.0), (3.0, 1.04), (3.0, 1.08), (3.0, 1.12), (3.0, 1.16), (3.0, 1.2), (3.0, 1.24), (3.0, 1.28), (3.0, 1.32), (3.0, 1.3599999999999999), (3.0, 1.4), (3.0, 1.44), (3.0, 1.48), (3.0, 1.52), (3.0, 1.56), (3.0, 1.6), (3.0, 1.6400000000000001), (3.0, 1.6800000000000002), (3.0, 1.72), (3.0, 1.76), (3.0, 1.8), (3.0, 1.8399999999999999), (3.0, 1.88), (3.0, 1.92), (3.0, 1.96), (3.0, 2.0), (3.0, 2.04), (3.0, 2.08), (3.0, 2.12), (3.0, 2.16), (3.0, 2.2), (3.0, 2.24), (3.0, 2.2800000000000002), (3.0, 2.3200000000000003), (3.0, 2.3600000000000003), (3.0, 2.4000000000000004), (3.0, 2.44), (3.0, 2.48), (3.0, 2.52), (3.0, 2.56), (3.0, 2.6), (3.0, 2.64), (3.0, 2.6799999999999997), (3.0, 2.7199999999999998), (3.0, 2.76), (3.0, 2.8), (3.0, 2.84), (3.0, 2.88), (3.0, 2.92), (3.0, 2.96), (3.0, 3.0)])

# %%
grid.play()
# Out:
# ('Loading new scene', 0)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x7fb343e7e7d0>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x7fb343e7e710>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x7fb343e7e810>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x7fb343d80090>)
# ('Point removed', <matplotlib.patches.Rectangle object at 0x7fb343d801d0>)
# ('Removing old scene', 0)
# ('Loading new scene', 1)
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
